# %% [markdown]
# # Auto-Model-Build v2 — thin driver
#
# Thin driver: collect inputs → call an **engine** → render artifacts. No `exec()` of generated code.
#
# Two engines (identical results, different control model):
# - **`graph`** — LangGraph orchestrator; HITL via interrupt/resume; set `INTERACTIVE=True` to be prompted at each gate.
# - **`linear`** — one-shot procedure; HITL auto-accepts.
#
# Runs offline unless `USE_LLM=True` (then needs `GOOGLE_API_KEY`).

# %%
# !pip install -r requirements-v2.txt
# Out:
# Ignoring eval_type_backport: markers 'python_version < "3.10"' don't match your environment
# Requirement already satisfied: numpy in c:\users\athar\anaconda3\lib\site-packages (from -r requirements-v2.txt (line 2)) (1.26.4)
# Requirement already satisfied: pandas in c:\users\athar\anaconda3\lib\site-packages (from -r requirements-v2.txt (line 3)) (2.2.2)
# Requirement already satisfied: scipy in c:\users\athar\anaconda3\lib\site-packages (from -r requirements-v2.txt (line 4)) (1.13.1)
# Requirement already satisfied: scikit-learn in c:\users\athar\anaconda3\lib\site-packages (from -r requirements-v2.txt (line 5)) (1.5.1)
# Requirement already satisfied: statsmodels in c:\users\athar\anaconda3\lib\site-packages (from -r requirements-v2.txt (line 6)) (0.14.2)
# Requirement already satisfied: pydantic>=2 in c:\users\athar\anaconda3\lib\site-packages (from -r requirements-v2.txt (line 7)) (2.13.4)
# Requirement already satisfied: optuna in c:\users\athar\anaconda3\lib\site-packages (from -r requirements-v2.txt (line 8)) (4.9.0)
# Requirement already satisfied: joblib in c:\users\athar\anaconda3\lib\site-packages (from -r requirements-v2.txt (line 9)) (1.4.2)
# Requirement already satisfied: matplotlib in c:\users\athar\anaconda3\lib\site-packages (from -r requirements-v2.txt (line 10)) (3.9.2)
# Requirement already satisfied: lightgbm in c:\users\athar\anaconda3\lib\site-packages (from -r requirements-v2.txt (line 14)) (4.6.0)
# Requirement already satisfied: xgboost in c:\users\athar\anaconda3\lib\site-packages (from -r requirements-v2.txt (line 15)) (3.2.0)
# Requirement already satisfied: langgraph in c:\users\athar\anaconda3\lib\site-packages (from -r requirements-v2.txt (line 18)) (1.2.4)
# Requirement already satisfied: langchain-core in c:\users\athar\anaconda3\lib\site-packages (from -r requirements-v2.txt (line 21)) (1.4.1)
# Requirement already satisfied: langchain-google-genai in c:\users\athar\anaconda3\lib\site-packages (from -r requirements-v2.txt (line 22)) (4.2.4)
# Requirement already satisfied: tavily-python in c:\users\athar\anaconda3\lib\site-packages (from -r requirements-v2.txt (line 23)) (0.7.26)
# Requirement already satisfied: pytest in c:\users\athar\anaconda3\lib\site-packages (from -r requirements-v2.txt (line 26)) (7.4.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\athar\anaconda3\lib\site-packages (from pandas->-r requirements-v2.txt (line 3)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\athar\anaconda3\lib\site-packages (from pandas->-r requirements-v2.txt (line 3)) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\athar\anaconda3\lib\site-packages (from pandas->-r requirements-v2.txt (line 3)) (2023.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\athar\anaconda3\lib\site-packages (from scikit-learn->-r requirements-v2.txt (line 5)) (3.5.0)
# Requirement already satisfied: patsy>=0.5.6 in c:\users\athar\anaconda3\lib\site-packages (from statsmodels->-r requirements-v2.txt (line 6)) (0.5.6)
# Requirement already satisfied: packaging>=21.3 in c:\users\athar\anaconda3\lib\site-packages (from statsmodels->-r requirements-v2.txt (line 6)) (24.1)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\athar\anaconda3\lib\site-packages (from pydantic>=2->-r requirements-v2.txt (line 7)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in c:\users\athar\anaconda3\lib\site-packages (from pydantic>=2->-r requirements-v2.txt (line 7)) (2.46.4)
# Requirement already satisfied: typing-extensions>=4.14.1 in c:\users\athar\anaconda3\lib\site-packages (from pydantic>=2->-r requirements-v2.txt (line 7)) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\athar\anaconda3\lib\site-packages (from pydantic>=2->-r requirements-v2.txt (line 7)) (0.4.2)
# Requirement already satisfied: alembic>=1.5.0 in c:\users\athar\anaconda3\lib\site-packages (from optuna->-r requirements-v2.txt (line 8)) (1.18.4)
# Requirement already satisfied: colorlog in c:\users\athar\anaconda3\lib\site-packages (from optuna->-r requirements-v2.txt (line 8)) (6.10.1)
# Requirement already satisfied: sqlalchemy>=1.4.2 in c:\users\athar\anaconda3\lib\site-packages (from optuna->-r requirements-v2.txt (line 8)) (2.0.34)
# Requirement already satisfied: tqdm in c:\users\athar\anaconda3\lib\site-packages (from optuna->-r requirements-v2.txt (line 8)) (4.66.5)
# Requirement already satisfied: PyYAML in c:\users\athar\anaconda3\lib\site-packages (from optuna->-r requirements-v2.txt (line 8)) (6.0.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\athar\anaconda3\lib\site-packages (from matplotlib->-r requirements-v2.txt (line 10)) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\athar\anaconda3\lib\site-packages (from matplotlib->-r requirements-v2.txt (line 10)) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\athar\anaconda3\lib\site-packages (from matplotlib->-r requirements-v2.txt (line 10)) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\athar\anaconda3\lib\site-packages (from matplotlib->-r requirements-v2.txt (line 10)) (1.4.4)
# Requirement already satisfied: pillow>=8 in c:\users\athar\anaconda3\lib\site-packages (from matplotlib->-r requirements-v2.txt (line 10)) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\athar\anaconda3\lib\site-packages (from matplotlib->-r requirements-v2.txt (line 10)) (3.1.2)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=4.1.0 in c:\users\athar\anaconda3\lib\site-packages (from langgraph->-r requirements-v2.txt (line 18)) (4.1.1)
# Requirement already satisfied: langgraph-prebuilt<1.2.0,>=1.1.0 in c:\users\athar\anaconda3\lib\site-packages (from langgraph->-r requirements-v2.txt (line 18)) (1.1.0)
# Requirement already satisfied: langgraph-sdk<0.5.0,>=0.4.2 in c:\users\athar\anaconda3\lib\site-packages (from langgraph->-r requirements-v2.txt (line 18)) (0.4.2)
# Requirement already satisfied: xxhash>=3.5.0 in c:\users\athar\anaconda3\lib\site-packages (from langgraph->-r requirements-v2.txt (line 18)) (3.7.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\athar\anaconda3\lib\site-packages (from langchain-core->-r requirements-v2.txt (line 21)) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.14 in c:\users\athar\anaconda3\lib\site-packages (from langchain-core->-r requirements-v2.txt (line 21)) (0.0.16)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\athar\anaconda3\lib\site-packages (from langchain-core->-r requirements-v2.txt (line 21)) (0.8.9)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\athar\anaconda3\lib\site-packages (from langchain-core->-r requirements-v2.txt (line 21)) (9.1.4)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\athar\anaconda3\lib\site-packages (from langchain-core->-r requirements-v2.txt (line 21)) (0.16.0)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in c:\users\athar\anaconda3\lib\site-packages (from langchain-google-genai->-r requirements-v2.txt (line 22)) (1.2.0)
# Requirement already satisfied: google-genai<3.0.0,>=1.65.0 in c:\users\athar\anaconda3\lib\site-packages (from langchain-google-genai->-r requirements-v2.txt (line 22)) (2.8.0)
# Requirement already satisfied: requests in c:\users\athar\anaconda3\lib\site-packages (from tavily-python->-r requirements-v2.txt (line 23)) (2.34.2)
# Requirement already satisfied: tiktoken>=0.5.1 in c:\users\athar\anaconda3\lib\site-packages (from tavily-python->-r requirements-v2.txt (line 23)) (0.13.0)
# Requirement already satisfied: httpx in c:\users\athar\anaconda3\lib\site-packages (from tavily-python->-r requirements-v2.txt (line 23)) (0.28.1)
# Requirement already satisfied: iniconfig in c:\users\athar\anaconda3\lib\site-packages (from pytest->-r requirements-v2.txt (line 26)) (1.1.1)
# Requirement already satisfied: pluggy<2.0,>=0.12 in c:\users\athar\anaconda3\lib\site-packages (from pytest->-r requirements-v2.txt (line 26)) (1.0.0)
# Requirement already satisfied: colorama in c:\users\athar\anaconda3\lib\site-packages (from pytest->-r requirements-v2.txt (line 26)) (0.4.6)
# Requirement already satisfied: Mako in c:\users\athar\anaconda3\lib\site-packages (from alembic>=1.5.0->optuna->-r requirements-v2.txt (line 8)) (1.3.12)
# Requirement already satisfied: anyio<5.0.0,>=4.8.0 in c:\users\athar\anaconda3\lib\site-packages (from google-genai<3.0.0,>=1.65.0->langchain-google-genai->-r requirements-v2.txt (line 22)) (4.13.0)
# Requirement already satisfied: google-auth<3.0.0,>=2.48.1 in c:\users\athar\anaconda3\lib\site-packages (from google-auth[requests]<3.0.0,>=2.48.1->google-genai<3.0.0,>=1.65.0->langchain-google-genai->-r requirements-v2.txt (line 22)) (2.53.0)
# Requirement already satisfied: websockets<17.0,>=13.0.0 in c:\users\athar\anaconda3\lib\site-packages (from google-genai<3.0.0,>=1.65.0->langchain-google-genai->-r requirements-v2.txt (line 22)) (15.0.1)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\athar\anaconda3\lib\site-packages (from google-genai<3.0.0,>=1.65.0->langchain-google-genai->-r requirements-v2.txt (line 22)) (1.9.0)
# Requirement already satisfied: sniffio in c:\users\athar\anaconda3\lib\site-packages (from google-genai<3.0.0,>=1.65.0->langchain-google-genai->-r requirements-v2.txt (line 22)) (1.3.1)
# Requirement already satisfied: certifi in c:\users\athar\anaconda3\lib\site-packages (from httpx->tavily-python->-r requirements-v2.txt (line 23)) (2026.5.20)
# Requirement already satisfied: httpcore==1.* in c:\users\athar\anaconda3\lib\site-packages (from httpx->tavily-python->-r requirements-v2.txt (line 23)) (1.0.9)
# Requirement already satisfied: idna in c:\users\athar\anaconda3\lib\site-packages (from httpx->tavily-python->-r requirements-v2.txt (line 23)) (3.18)
# Requirement already satisfied: h11>=0.16 in c:\users\athar\anaconda3\lib\site-packages (from httpcore==1.*->httpx->tavily-python->-r requirements-v2.txt (line 23)) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\athar\anaconda3\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core->-r requirements-v2.txt (line 21)) (2.1)
# Requirement already satisfied: ormsgpack>=1.12.0 in c:\users\athar\anaconda3\lib\site-packages (from langgraph-checkpoint<5.0.0,>=4.1.0->langgraph->-r requirements-v2.txt (line 18)) (1.12.2)
# Requirement already satisfied: orjson>=3.11.5 in c:\users\athar\anaconda3\lib\site-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph->-r requirements-v2.txt (line 18)) (3.11.9)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\athar\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core->-r requirements-v2.txt (line 21)) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\athar\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core->-r requirements-v2.txt (line 21)) (0.23.0)
# Requirement already satisfied: six in c:\users\athar\anaconda3\lib\site-packages (from patsy>=0.5.6->statsmodels->-r requirements-v2.txt (line 6)) (1.16.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\athar\anaconda3\lib\site-packages (from requests->tavily-python->-r requirements-v2.txt (line 23)) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\athar\anaconda3\lib\site-packages (from requests->tavily-python->-r requirements-v2.txt (line 23)) (2.7.0)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\athar\anaconda3\lib\site-packages (from sqlalchemy>=1.4.2->optuna->-r requirements-v2.txt (line 8)) (3.0.1)
# Requirement already satisfied: regex in c:\users\athar\anaconda3\lib\site-packages (from tiktoken>=0.5.1->tavily-python->-r requirements-v2.txt (line 23)) (2024.9.11)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\athar\anaconda3\lib\site-packages (from google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai<3.0.0,>=1.65.0->langchain-google-genai->-r requirements-v2.txt (line 22)) (0.4.2)
# Requirement already satisfied: cryptography>=38.0.3 in c:\users\athar\anaconda3\lib\site-packages (from google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai<3.0.0,>=1.65.0->langchain-google-genai->-r requirements-v2.txt (line 22)) (48.0.0)
# Requirement already satisfied: MarkupSafe>=0.9.2 in c:\users\athar\anaconda3\lib\site-packages (from Mako->alembic>=1.5.0->optuna->-r requirements-v2.txt (line 8)) (2.1.3)
# Requirement already satisfied: cffi>=2.0.0 in c:\users\athar\anaconda3\lib\site-packages (from cryptography>=38.0.3->google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai<3.0.0,>=1.65.0->langchain-google-genai->-r requirements-v2.txt (line 22)) (2.0.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in c:\users\athar\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai<3.0.0,>=1.65.0->langchain-google-genai->-r requirements-v2.txt (line 22)) (0.6.3)
# Requirement already satisfied: pycparser in c:\users\athar\anaconda3\lib\site-packages (from cffi>=2.0.0->cryptography>=38.0.3->google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai<3.0.0,>=1.65.0->langchain-google-genai->-r requirements-v2.txt (line 22)) (3.0)

# %%
import os
import getpass
import pandas as pd

# ── 1) Data inputs ──────────────────────────────────────────────────────────
print("=== Data & Column Configuration ===")
DATA_PATH  = input("Data file path (CSV or Parquet): ").strip()
TARGET_COL = input("Target column name: ").strip()
DATE_COL   = input("Date/snapshot column name: ").strip()
GROUP_COL  = input("Group/customer-id column name (leave blank to skip): ").strip() or None
OBJECTIVE  = input("Business objective [Build CC propensity model]: ").strip() or "Build CC propensity model"

# ── 2) Run settings ─────────────────────────────────────────────────────────
print("\n=== Run Settings ===")
_engine_raw = input("Engine — graph or linear [graph]: ").strip().lower()
ENGINE = _engine_raw if _engine_raw in ("graph", "linear") else "graph"

_interactive_raw = input("Interactive HITL gates? (graph only) y/n [y]: ").strip().lower()
INTERACTIVE = _interactive_raw not in ("n", "no", "false", "0")

_use_llm_raw = input("Enable LLM advisor plane (needs API key)? y/n [n]: ").strip().lower()
USE_LLM = _use_llm_raw in ("y", "yes", "true", "1")

_rounds_raw = input("Search rounds [2]: ").strip()
SEARCH_ROUNDS = int(_rounds_raw) if _rounds_raw.isdigit() else 2

# ── 3) API keys (only prompted when LLM is enabled) ─────────────────────────
if USE_LLM:
    print("\n=== API Keys (input is hidden) ===")
    _gkey = getpass.getpass("GOOGLE_API_KEY (Gemini): ").strip()
    if _gkey:
        os.environ["GOOGLE_API_KEY"] = _gkey

    _tkey = getpass.getpass("TAVILY_API_KEY (optional, press Enter to skip): ").strip()
    if _tkey:
        os.environ["TAVILY_API_KEY"] = _tkey

# ── 4) Load data ─────────────────────────────────────────────────────────────
df = (pd.read_parquet(DATA_PATH)
      if DATA_PATH.endswith((".parquet", ".pq"))
      else pd.read_csv(DATA_PATH, low_memory=False))

print(f"\n✓ Loaded: {df.shape[0]:,} rows × {df.shape[1]} cols")
print(f"  target={TARGET_COL}  date={DATE_COL}  group={GROUP_COL}")
print(f"  engine={ENGINE}  interactive={INTERACTIVE}  use_llm={USE_LLM}  rounds={SEARCH_ROUNDS}")
# Out:
# === Data & Column Configuration ===
# Data file path (CSV or Parquet):  cc_upsell_propensity_dataset.csv
# Target column name:  cc_conversion_next_1m
# Date/snapshot column name:  snapshot_month
# Group/customer-id column name (leave blank to skip):
# Business objective [Build CC propensity model]:  Build CC propensity model
# === Run Settings ===
# Engine — graph or linear [graph]:  graph
# Interactive HITL gates? (graph only) y/n [y]:  y
# Enable LLM advisor plane (needs API key)? y/n [n]:  y
# Search rounds [2]:  2
# === API Keys (input is hidden) ===
# GOOGLE_API_KEY (Gemini):  ········
# TAVILY_API_KEY (optional, press Enter to skip):  ········
# ✓ Loaded: 600,000 rows × 50 cols
#   target=cc_conversion_next_1m  date=snapshot_month  group=None
#   engine=graph  interactive=True  use_llm=True  rounds=2

# %%
# 2) Optional: enable the LLM advisor plane (deterministic + cached, temperature=0)
cached_llm = None
if USE_LLM:
    from advisors.llm import build_llm, CachedLLM
    model_id = "gemini-2.5-flash-lite"
    
    cached_llm = CachedLLM(build_llm(model_id), cache_dir="artifacts/runs/_llm_cache", model_id=model_id)
    print("LLM advisor plane ON")
else:
    print("Offline (deterministic) — no API key used")
# Out:
# LLM advisor plane ON

# %%
# ── 3) HITL helpers + run engine ─────────────────────────────────────────────

_W    = 64
_BAR  = "═" * _W
_THIN = "─" * _W

# Stages that expose value overrides; others only get Accept / Regenerate
_OVERRIDE_STAGES = {"model_design"}

_OVERRIDE_PATHS = {
    "primary_metric":          "primary_metric",
    "algorithms":              "search.algorithms",
    "n_trials":                "search.n_trials",
    "imbalance_tier":          "data_strategy.imbalance_tier",
    "correlation_threshold":   "data_strategy.correlation_threshold",
    "psi_threshold":           "data_strategy.psi_threshold",
    "scaling_required":        "data_strategy.scaling_required",
}

def _parse_value(v):
    v = v.strip()
    if "," in v:
        return [x.strip() for x in v.split(",") if x.strip()]
    if v.lower() in ("true", "false"):
        return v.lower() == "true"
    try:   return int(v)
    except ValueError: pass
    try:   return float(v)
    except ValueError: return v

def _hitl_ui(stage, decisions):
    """Rich HITL prompt: numbered choices, guided override menu."""
    can_override = stage in _OVERRIDE_STAGES

    print(f"\n{_BAR}")
    print(f"  🔔  HITL GATE  ─  {stage.upper()}")
    print(_BAR)
    print("  Agent decisions:")
    for k, v in decisions.items():
        vstr = str(v)
        if len(vstr) > 50: vstr = vstr[:47] + "..."
        print(f"    •  {k:<28}  {vstr}")
    print(_THIN)
    if can_override:
        print("    [1]  Accept      — proceed with these decisions  (default)")
        print("    [2]  Override    — change specific values interactively")
        print("    [3]  Regenerate  — re-run this step with your feedback")
        prompt = "  Your choice (1 / 2 / 3, or Enter = Accept): "
    else:
        print("    [1]  Accept      — proceed  (default)")
        print("    [3]  Regenerate  — re-run this step with your feedback")
        prompt = "  Your choice (1 / 3, or Enter = Accept): "
    print(_BAR)
    choice = input(prompt).strip() or "1"

    # ── Regenerate ────────────────────────────────────────────────────────
    if choice == "3":
        fb = input("  Describe what to change: ").strip()
        print(f"  ↩  Regenerating with your feedback...")
        return {"action": "regenerate", "instructions": fb, "overrides": {}}

    # ── Override ──────────────────────────────────────────────────────────
    if choice == "2" and can_override:
        params = list(_OVERRIDE_PATHS.keys())
        overrides = {}
        print(f"\n{_THIN}")
        print("  Overridable parameters:")
        for i, k in enumerate(params):
            cur = decisions.get(k, "—")
            print(f"    {chr(97+i)})  {k:<28}  current: {cur}")
        print(_THIN)
        print("  Enter a letter to edit a parameter. Press Enter alone to finish.")
        while True:
            sel = input("  Letter (or Enter to finish): ").strip().lower()
            if not sel:
                break
            idx = ord(sel[0]) - 97
            if not (0 <= idx < len(params)):
                print(f"  ✗  '{sel}' is not a valid option.")
                continue
            key  = params[idx]
            path = _OVERRIDE_PATHS[key]
            cur  = decisions.get(key, "—")
            raw  = input(f"  New value for [{key}]  (current: {cur}): ").strip()
            if not raw:
                print("  (skipped)")
                continue
            val = _parse_value(raw)
            if path.endswith("algorithms") and not isinstance(val, list):
                val = [val]
            overrides[path] = val
            print(f"  ✓  {key} → {val}")
        if overrides:
            print(f"\n  → Overrides: {overrides}")
            return {"action": "override", "overrides": overrides, "instructions": ""}
        print("  → No changes made, accepting.")

    # ── Accept ────────────────────────────────────────────────────────────
    print("  ✓  Accepted — proceeding.\n")
    return {"action": "accept", "overrides": {}, "instructions": ""}

# Adapters for the two engines
def _interactive_resolver(payload):           # graph engine
    return _hitl_ui(payload["stage"], payload["decisions"])

def _hitl_callable(stage, decisions):         # linear engine
    return _hitl_ui(stage, decisions)

# ── Run ───────────────────────────────────────────────────────────────────────
common = dict(
    business_objective=OBJECTIVE,
    target_col=TARGET_COL, date_col=DATE_COL, group_col=GROUP_COL,
    cached_llm=cached_llm, source_path=DATA_PATH, search_rounds=SEARCH_ROUNDS,
)

if ENGINE == "graph":
    from app import graph
    resolver = _interactive_resolver if INTERACTIVE else None
    out = graph.run_graph(df, resolver=resolver, **common)
    result, model, prepared, summary = (
        out["result"], out["best_model"], out["prepared"], out["summary"])
    gates_info = f"gates seen: {out['gates_seen']}"
else:
    from app import orchestrator
    hitl_mode = _hitl_callable if INTERACTIVE else "auto"
    result, model, prepared, summary = orchestrator.run(
        df, hitl_mode=hitl_mode, **common)
    gates_info = "interactive HITL" if INTERACTIVE else "auto (no prompts)"

print(f"\n{_BAR}")
print(f"  ✅  RUN COMPLETE  —  {ENGINE} engine  ({gates_info})")
print(_THIN)
print(f"  Best algorithm   :  {result.best_algorithm}")
print(f"  Primary metric   :  {result.primary_metric}")
print(f"  Trials run       :  {result.n_trials_run}")
print(f"  Artifacts at     :  {result.run_dir}")
print(_BAR)
# Out:
# ════════════════════════════════════════════════════════════════
#   STEP 1  ▶  alias columns (privacy shield)
# ────────────────────────────────────────────────────────────────
#   ✓  Completed in 0.09s
#
# ════════════════════════════════════════════════════════════════
#   STEP 2  ▶  profile data
# ────────────────────────────────────────────────────────────────
#   ✓  Completed in 3.38s
#
# ════════════════════════════════════════════════════════════════
#   🔔  HITL GATE  ─  PROFILING
# ════════════════════════════════════════════════════════════════
#   Agent decisions:
#     •  n_rows                        600000
#     •  pos_ratio                     0.0503
#     •  n_snapshots                   6
# ────────────────────────────────────────────────────────────────
#     [1]  Accept      — proceed  (default)
#     [3]  Regenerate  — re-run this step with your feedback
# ════════════════════════════════════════════════════════════════
#   Your choice (1 / 3, or Enter = Accept):
# Deserializing unregistered type contracts.results.ProfileResult from checkpoint. This will be blocked in a future version. Set LANGGRAPH_STRICT_MSGPACK=true to block now, or add to allowed_msgpack_modules to allow explicitly: [('contracts.results', 'ProfileResult')]
#   ✓  Accepted — proceeding.
#
#
# ════════════════════════════════════════════════════════════════
#   STEP 3  ▶  research (models / windows / HPO / features)
# ────────────────────────────────────────────────────────────────
#    $ research: in=358 cached=0 out=1327 think=0 ~$0.000567
#      ↳  [research/models]
#         Decision : Recommended models: ['LightGBM', 'XGBoost', 'HistGradientBoosting']
#         Why      : Gradient boosting models like LightGBM, XGBoost, and Hi
#                    stGradientBoosting are highly effective for tabular dat
#                    a and can handle moderate class imbalance well. They of
#                    fer good performance and interpretability, crucial for
#                    banking applications. Logistic Regression is a good bas
#                    eline but may struggle with complex interactions. Rando
#                    mForest is also a strong contender but can be slower th
#                    an gradient boosting methods for large datasets.
#         Source   : Gemini + web: ['https://www.altexsoft.com/blog/propensity-model', 'https://antonsruberts.github.io/propensity-model', 'https://www.oajaiml.com/uploads/archivepdf/237151184.pdf', 'https://medium.com/data-science/why-you-should-do-feature-engineering-first-hyperparameter-tuning-second-as-a-data-scientist-334be5eb276c', 'https://www.artefact.com/blog/scoring-customer-propensity-using-machine-learning-models-on-google-analytics-data']
#      ↳  [research/windows]
#         Decision : observation=5m, OOT=1 snapshot(s)
#         Why      : Using 5 months for observation and 1 month for out-of-t
#                    ime (OOT) validation provides a sufficient lookback per
#                    iod to capture customer behavior trends while ensuring
#                    a recent and relevant OOT set for performance evaluatio
#                    n, aligning with the monthly snapshot data.
#         Source   : Gemini + web: ['https://www.altexsoft.com/blog/propensity-model', 'https://antonsruberts.github.io/propensity-model', 'https://www.oajaiml.com/uploads/archivepdf/237151184.pdf', 'https://medium.com/data-science/why-you-should-do-feature-engineering-first-hyperparameter-tuning-second-as-a-data-scientist-334be5eb276c', 'https://www.artefact.com/blog/scoring-customer-propensity-using-machine-learning-models-on-google-analytics-data']
#      ↳  [research/hpo]
#         Decision : HPO ranges proposed for: ['LightGBM', 'XGBoost', 'HistGradientBoosting']
#         Why      : Hyperparameter optimization is crucial for maximizing m
#                    odel performance. The provided spaces cover key paramet
#                    ers for LightGBM, XGBoost, and HistGradientBoosting, fo
#                    cusing on learning rate, tree complexity, and regulariz
#                    ation. Feature engineering should precede HPO, as state
#                    d in https://medium.com/data-science/why-you-should-do-
#                    feature-engineering-first-hyperparameter-tuning-second-
#                    as-a-data-scientist-334be5eb276c.
#         Source   : Gemini + web: ['https://www.altexsoft.com/blog/propensity-model', 'https://antonsruberts.github.io/propensity-model', 'https://www.oajaiml.com/uploads/archivepdf/237151184.pdf', 'https://medium.com/data-science/why-you-should-do-feature-engineering-first-hyperparameter-tuning-second-as-a-data-scientist-334be5eb276c', 'https://www.artefact.com/blog/scoring-customer-propensity-using-machine-learning-models-on-google-analytics-data']
#   ✓  Completed in 9.8s
#
# ════════════════════════════════════════════════════════════════
#   STEP 4  ▶  domain feature engineering (research families)
# ────────────────────────────────────────────────────────────────
#      ↳  [feature_engineering/families]
#         Decision : Suggested families: ['Demographics', 'Transaction History', 'Existing Products & Services', 'Credit Bureau Data', 'Engagement Metrics']
#         Why      : A comprehensive set of feature families is essential fo
#                    r building a robust propensity model. These families co
#                    ver demographic, behavioral, financial, and engagement
#                    aspects of customers, drawing from established practice
#                    s in propensity modeling (e.g., https://www.altexsoft.c
#                    om/blog/propensity-model, https://antonsruberts.github.
#                    io/propensity-model, https://www.artefact.com/blog/scor
#                    ing-customer-propensity-using-machine-learning-models-o
#                    n-google-analytics-data). Feature engineering will be c
#                    ritical to extract meaningful signals from these raw da
#                    ta points, as highlighted in https://medium.com/data-sc
#                    ience/why-you-should-do-feature-engineering-first-hyper
#                    parameter-tuning-second-as-a-data-scientist-334be5eb276
#                    c.
#         Source   : Gemini + web: ['https://www.altexsoft.com/blog/propensity-model', 'https://antonsruberts.github.io/propensity-model', 'https://www.oajaiml.com/uploads/archivepdf/237151184.pdf', 'https://medium.com/data-science/why-you-should-do-feature-engineering-first-hyperparameter-tuning-second-as-a-data-scientist-334be5eb276c', 'https://www.artefact.com/blog/scoring-customer-propensity-using-machine-learning-models-on-google-analytics-data']
#      · Feature-store match: resolved 6 concepts ['credit_3m', 'credit_6m', 'debit_3m', 'debit_6m', 'txn_count_3m', 'bounce_count_3m']; built 4 derived features ['credit_velocity_3m_6m', 'debit_velocity_3m_6m', 'credit_debit_ratio_3m', 'bounce_rate_3m']
#   ✓  Completed in 0.94s
#
# ════════════════════════════════════════════════════════════════
#   STEP 5  ▶  model design
# ────────────────────────────────────────────────────────────────
#      ↳  [model_design/algorithms]
#         Decision : Shortlist applied: ['LightGBM', 'XGBoost', 'HistGradientBoosting']
#         Why      : Gradient boosting models like LightGBM, XGBoost, and Hi
#                    stGradientBoosting are highly effective for tabular dat
#                    a and can handle moderate class imbalance well. They of
#                    fer good performance and interpretability, crucial for
#                    banking applications. Logistic Regression is a good bas
#                    eline but may struggle with complex interactions. Rando
#                    mForest is also a strong contender but can be slower th
#                    an gradient boosting methods for large datasets.
#         Source   : Gemini + web: ['https://www.altexsoft.com/blog/propensity-model', 'https://antonsruberts.github.io/propensity-model', 'https://www.oajaiml.com/uploads/archivepdf/237151184.pdf', 'https://medium.com/data-science/why-you-should-do-feature-engineering-first-hyperparameter-tuning-second-as-a-data-scientist-334be5eb276c', 'https://www.artefact.com/blog/scoring-customer-propensity-using-machine-learning-models-on-google-analytics-data']
#      ↳  [model_design/windows]
#         Decision : train=['2025-01', '2025-02', '2025-03', '2025-04', '2025-05'], OOT=['2025-06']
#         Why      : Using 5 months for observation and 1 month for out-of-t
#                    ime (OOT) validation provides a sufficient lookback per
#                    iod to capture customer behavior trends while ensuring
#                    a recent and relevant OOT set for performance evaluatio
#                    n, aligning with the monthly snapshot data.
#         Source   : Gemini + web: ['https://www.altexsoft.com/blog/propensity-model', 'https://antonsruberts.github.io/propensity-model', 'https://www.oajaiml.com/uploads/archivepdf/237151184.pdf', 'https://medium.com/data-science/why-you-should-do-feature-engineering-first-hyperparameter-tuning-second-as-a-data-scientist-334be5eb276c', 'https://www.artefact.com/blog/scoring-customer-propensity-using-machine-learning-models-on-google-analytics-data']
#      ↳  [model_design/metric]
#         Decision : Primary metric: PR_AUC
#         Why      : deterministic metric policy for objective + tier 'moder
#                    ate'
#         Source   : deterministic policy
#      ↳  [model_design/hpo]
#         Decision : Using research HPO ranges for ['LightGBM', 'XGBoost', 'HistGradientBoosting']
#         Why      : Hyperparameter optimization is crucial for maximizing m
#                    odel performance. The provided spaces cover key paramet
#                    ers for LightGBM, XGBoost, and HistGradientBoosting, fo
#                    cusing on learning rate, tree complexity, and regulariz
#                    ation. Feature engineering should precede HPO, as state
#                    d in https://medium.com/data-science/why-you-should-do-
#                    feature-engineering-first-hyperparameter-tuning-second-
#                    as-a-data-scientist-334be5eb276c.
#         Source   : Gemini + web: ['https://www.altexsoft.com/blog/propensity-model', 'https://antonsruberts.github.io/propensity-model', 'https://www.oajaiml.com/uploads/archivepdf/237151184.pdf', 'https://medium.com/data-science/why-you-should-do-feature-engineering-first-hyperparameter-tuning-second-as-a-data-scientist-334be5eb276c', 'https://www.artefact.com/blog/scoring-customer-propensity-using-machine-learning-models-on-google-analytics-data']
#   ✓  Completed in 0.06s
#
# ════════════════════════════════════════════════════════════════
#   🔔  HITL GATE  ─  MODEL_DESIGN
# ════════════════════════════════════════════════════════════════
#   Agent decisions:
#     •  primary_metric                PR_AUC
#     •  algorithms                    ['LightGBM', 'XGBoost', 'HistGradientBoosting']
#     •  imbalance_tier                moderate
#     •  oot_snapshots                 ['2025-06']
#     •  correlation_threshold         0.85
# ────────────────────────────────────────────────────────────────
#     [1]  Accept      — proceed with these decisions  (default)
#     [2]  Override    — change specific values interactively
#     [3]  Regenerate  — re-run this step with your feedback
# ════════════════════════════════════════════════════════════════
#   Your choice (1 / 2 / 3, or Enter = Accept):
# Deserializing unregistered type contracts.config.RunConfig from checkpoint. This will be blocked in a future version. Set LANGGRAPH_STRICT_MSGPACK=true to block now, or add to allowed_msgpack_modules to allow explicitly: [('contracts.config', 'RunConfig')]
#   ✓  Accepted — proceeding.
#
#
# ════════════════════════════════════════════════════════════════
#   STEP 6  ▶  prepare data (split/clean/select/encode)
# ────────────────────────────────────────────────────────────────
#      · Feature selection: 52 → 40 (suspicious/leakage flags: 0)
#   ✓  Completed in 19.63s
#
# ════════════════════════════════════════════════════════════════
#   🔔  HITL GATE  ─  FEATURE_SELECTION
# ════════════════════════════════════════════════════════════════
#   Agent decisions:
#     •  n_in                          52
#     •  n_selected                    40
#     •  suspicious_high_iv            []
# ────────────────────────────────────────────────────────────────
#     [1]  Accept      — proceed  (default)
#     [3]  Regenerate  — re-run this step with your feedback
# ════════════════════════════════════════════════════════════════
#   Your choice (1 / 3, or Enter = Accept):
#   ✓  Accepted — proceeding.
#
#
# ════════════════════════════════════════════════════════════════
#   STEP 7  ▶  search round (HPO)
# ────────────────────────────────────────────────────────────────
#      · Round 1: ran 18 trials over ['LightGBM', 'XGBoost', 'HistGradientBoosting']; HPO ranges from research for ['LightGBM', 'XGBoost', 'HistGradientBoosting']
#   ✓  Completed in 1252.02s
#
# ════════════════════════════════════════════════════════════════
#   STEP 8  ▶  assess: continue or stop?
# ────────────────────────────────────────────────────────────────
#    $ stop_decision: in=103 cached=0 out=93 think=0 ~$0.000048
#   ✓  Completed in 3.02s
#
# ════════════════════════════════════════════════════════════════
#   STEP 9  ▶  strategist: revise algorithm budget
# ────────────────────────────────────────────────────────────────
#    $ strategist: in=94 cached=0 out=118 think=0 ~$0.000057
#   ✓  Completed in 4.72s
#
# ════════════════════════════════════════════════════════════════
#   STEP 10  ▶  search round (HPO)
# ────────────────────────────────────────────────────────────────
#      · Round 2: ran 18 trials over ['LightGBM', 'XGBoost', 'HistGradientBoosting']; HPO ranges from research for ['LightGBM', 'XGBoost', 'HistGradientBoosting']
#   ✓  Completed in 1263.98s
#
# ════════════════════════════════════════════════════════════════
#   STEP 11  ▶  assess: continue or stop?
# ────────────────────────────────────────────────────────────────
#   ✓  Completed in 0.01s
#
# ════════════════════════════════════════════════════════════════
#   STEP 12  ▶  finalize (refit + OOT eval + persist)
# ────────────────────────────────────────────────────────────────
#   ✓  Completed in 9.57s
#
# ════════════════════════════════════════════════════════════════
#   🔔  HITL GATE  ─  EVALUATION
# ════════════════════════════════════════════════════════════════
#   Agent decisions:
#     •  best_algorithm                HistGradientBoosting
#     •  oot                           {'precision': 0.0, 'recall': 0.0, 'f1': 0.0, 'r...
# ────────────────────────────────────────────────────────────────
#     [1]  Accept      — proceed  (default)
#     [3]  Regenerate  — re-run this step with your feedback
# ════════════════════════════════════════════════════════════════
#   Your choice (1 / 3, or Enter = Accept):
# Deserializing unregistered type contracts.results.TrialResult from checkpoint. This will be blocked in a future version. Set LANGGRAPH_STRICT_MSGPACK=true to block now, or add to allowed_msgpack_modules to allow explicitly: [('contracts.results', 'TrialResult')]
# Deserializing unregistered type contracts.results.RunResult from checkpoint. This will be blocked in a future version. Set LANGGRAPH_STRICT_MSGPACK=true to block now, or add to allowed_msgpack_modules to allow explicitly: [('contracts.results', 'RunResult')]
#   ✓  Accepted — proceeding.
#
#
# ════════════════════════════════════════════════════════════════
#   STEP 13  ▶  write model summary
# ────────────────────────────────────────────────────────────────
#    $ narrative: in=145 cached=0 out=132 think=0 ~$0.000067
#   ✓  Completed in 1.52s
#
# ════════════════════════════════════════════════════════════════
#   ✅  RUN COMPLETE  —  graph engine  (gates seen: ['profiling', 'model_design', 'feature_selection', 'evaluation'])
# ────────────────────────────────────────────────────────────────
#   Best algorithm   :  HistGradientBoosting
#   Primary metric   :  PR_AUC
#   Trials run       :  36
#   Artifacts at     :  artifacts\runs\2026-06-19_13-20-02
# ════════════════════════════════════════════════════════════════

# %%
# ── 4) Results Dashboard ─────────────────────────────────────────────────────
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import pandas as pd
import numpy as np

_W    = 64
_BAR  = "═" * _W
_THIN = "─" * _W

# real-name helpers
rev   = (result.column_alias_map or {}).get("reverse", {})
real1 = lambda n:     rev.get(n, n)
realN = lambda names: [rev.get(n, n) for n in (names or [])]

sel = prepared.selection_report
sr  = prepared.split_report

# Resolve primary_metric key in oot_metrics (config stores "PR_AUC", oot dict uses "pr_auc")
_sample_oot = next(
    (r.get("oot_metrics", {}) for r in result.leaderboard if r.get("oot_metrics")), {}
)
_pm_key = next(
    (k for k in _sample_oot if k.lower() == result.primary_metric.lower()),
    result.primary_metric.lower()          # fallback: lowercase
)
_pm_col = f"OOT {_pm_key}"                # column name used throughout leaderboard DataFrame

def _sec(n, title):
    print(f"\n{_BAR}\n  {n}  {title}\n{_THIN}")

# ══════════════════════════════════════════════════════════════════════════════
# 1. DATA SPLIT
# ══════════════════════════════════════════════════════════════════════════════
_sec("①", "DATA SPLIT")
split_df = pd.DataFrame([
    {"Set": "Train",
     "Rows": f"{sr.train_rows:,}",
     "Snapshots": " → ".join(sr.train_range) if sr.train_range else "—",
     "Positive ratio": f"{sr.train_pos_ratio:.2%}" if sr.train_pos_ratio is not None else "—"},
    {"Set": "OOT (hold-out)",
     "Rows": f"{sr.oot_rows:,}",
     "Snapshots": " → ".join(sr.oot_range) if sr.oot_range else "—",
     "Positive ratio": f"{sr.oot_pos_ratio:.2%}" if sr.oot_pos_ratio is not None else "—"},
])
print(split_df.to_string(index=False))

# ══════════════════════════════════════════════════════════════════════════════
# 2. FEATURE SELECTION FUNNEL
# ══════════════════════════════════════════════════════════════════════════════
_sec("②", "FEATURE SELECTION FUNNEL")
funnel_stages = [
    ("Input features",                       sel.n_in),
    ("After hygiene (constant/missing/card)", sel.n_after_hygiene),
    ("After univariate IV filter",            sel.n_after_univariate),
    ("After redundancy / corr pruning",       sel.n_after_redundancy),
    ("Final selected",                        sel.n_selected),
]
mx = sel.n_in or 1
for label, n in funnel_stages:
    bar_len = int(36 * n / mx)
    removed = sel.n_in - n
    marker  = "  ◀ FINAL" if label == "Final selected" else (f"  (removed {removed} total)" if removed else "")
    print(f"  {label:<44} {n:>4}  {'█' * bar_len}{marker}")

print(f"\n  Dropped by reason:")
drop_cats = [
    ("Constant / zero-variance",     sel.dropped_constant),
    ("High missing rate",            sel.dropped_high_missing),
    ("High cardinality categorical", sel.dropped_high_cardinality),
    ("Low IV (below threshold)",     sel.dropped_low_iv),
    ("Redundant (corr cluster)",     sel.dropped_redundant),
]
for label, lst in drop_cats:
    if not lst:
        continue
    names = ", ".join(realN(lst[:6])) + (f" … +{len(lst)-6} more" if len(lst) > 6 else "")
    print(f"    • {label:<36} ({len(lst):>3})  {names}")
if sel.suspicious_high_iv:
    names = ", ".join(realN(sel.suspicious_high_iv[:6]))
    print(f"    ⚠️  Leakage suspects (high IV, flagged not dropped)  "
          f"({len(sel.suspicious_high_iv)})  {names}")

# ══════════════════════════════════════════════════════════════════════════════
# 3. IV TABLE — SELECTED FEATURES
# ══════════════════════════════════════════════════════════════════════════════
_sec("③", "INFORMATION VALUE — SELECTED FEATURES  (real names, top 20)")
selected_set = set(sel.selected_features)
iv_rows = sorted(
    [r for r in sel.iv_table if r["feature"] in selected_set],
    key=lambda r: r.get("iv", 0), reverse=True
)[:20]
if iv_rows:
    iv_df = pd.DataFrame([
        {
            "Feature":  real1(r["feature"]),
            "IV":       round(r.get("iv", 0), 4),
            "IV band":  r.get("iv_band", ""),
            "Leakage?": "⚠️" if r["feature"] in sel.suspicious_high_iv else "",
        }
        for r in iv_rows
    ])
    print(iv_df.to_string(index=False))

    fig, ax = plt.subplots(figsize=(9, max(3, len(iv_df) * 0.36 + 1)))
    colors_iv = ["#E53935" if r["feature"] in sel.suspicious_high_iv else "#1565C0"
                 for r in iv_rows]
    ax.barh(iv_df["Feature"][::-1], iv_df["IV"][::-1], color=colors_iv[::-1])
    ax.set_xlabel("Information Value (IV)")
    ax.set_title("IV — Selected Features  (red = leakage suspect)")
    ax.axvline(0.02, color="orange", lw=1, ls="--", label="weak (0.02)")
    ax.axvline(0.1,  color="green",  lw=1, ls="--", label="medium (0.10)")
    ax.legend(fontsize=8)
    plt.tight_layout()
    plt.show()
else:
    print("  (no IV data available)")

# ══════════════════════════════════════════════════════════════════════════════
# 4. MODEL LEADERBOARD
# ══════════════════════════════════════════════════════════════════════════════
_sec("④", "MODEL LEADERBOARD — ALL TRIALS")

# Deduplicate: keep one row per (algorithm, cv_score) pair with best OOT primary metric
_seen: dict = {}
unique_rows = []
for r in result.leaderboard:
    key = (r["algorithm"], round(r.get("cv_score", 0), 5))
    oot_pm = r.get("oot_metrics", {}).get(_pm_key, 0)
    if key not in _seen or oot_pm > _seen[key]:
        _seen[key] = oot_pm
        unique_rows.append(r)

oot_keys = sorted({k for r in unique_rows for k in r.get("oot_metrics", {})})

# Best OOT primary metric per algorithm (for the ★ marker)
_best_oot_per_algo = {}
for r in unique_rows:
    a = r["algorithm"]
    v = r.get("oot_metrics", {}).get(_pm_key, 0)
    _best_oot_per_algo[a] = max(_best_oot_per_algo.get(a, 0), v)

lb_records = []
for r in unique_rows:
    oot_pm_val = r.get("oot_metrics", {}).get(_pm_key, 0)
    is_best = (r["algorithm"] == result.best_algorithm and
               oot_pm_val == _best_oot_per_algo.get(result.best_algorithm, 0))
    rec = {
        "★":         "★" if is_best else "",
        "Algorithm": r["algorithm"],
        "CV score":  round(r.get("cv_score", 0), 4),
    }
    for k in oot_keys:
        rec[f"OOT {k}"] = round(r.get("oot_metrics", {}).get(k, float("nan")), 4)
    lb_records.append(rec)

lb_display = (pd.DataFrame(lb_records)
                .sort_values(_pm_col, ascending=False)
                .reset_index(drop=True))
print(lb_display.to_string(index=False))

# Best-per-algorithm bar chart
best_per_algo = (lb_display.groupby("Algorithm")[_pm_col].max()
                           .sort_values(ascending=False))
fig, ax = plt.subplots(figsize=(8, max(3, len(best_per_algo) * 0.55 + 1)))
colors_lb = ["#2E7D32" if a == result.best_algorithm else "#90A4AE"
             for a in best_per_algo.index]
bars = ax.barh(best_per_algo.index[::-1], best_per_algo.values[::-1], color=colors_lb[::-1])
ax.bar_label(bars, fmt="%.4f", padding=5, fontsize=9)
ax.set_xlabel(_pm_col)
ax.set_title(f"Best {_pm_col} per Algorithm  (★ = winner)")
ax.set_xlim(0, best_per_algo.max() * 1.18)
plt.tight_layout()
plt.show()

# ══════════════════════════════════════════════════════════════════════════════
# 5. FEATURE IMPORTANCE — BEST MODEL
# ══════════════════════════════════════════════════════════════════════════════
_sec("⑤", f"FEATURE IMPORTANCE — {result.best_algorithm}  (top 20, real names)")
fi = None
if hasattr(model, "feature_importances_"):
    fi = model.feature_importances_
elif hasattr(model, "coef_"):
    fi = np.abs(model.coef_[0] if model.coef_.ndim > 1 else model.coef_)

fnames = realN(prepared.feature_names) if prepared.feature_names else []
if fi is not None and fnames:
    fi_norm = fi / (fi.sum() or 1)
    fi_df = (pd.DataFrame({"Feature": fnames, "Importance": fi_norm})
               .sort_values("Importance", ascending=False).head(20))
    print(fi_df.to_string(index=False))

    fig, ax = plt.subplots(figsize=(9, max(4, len(fi_df) * 0.38 + 1)))
    cmap = plt.cm.Blues_r(np.linspace(0.15, 0.65, len(fi_df)))
    bars = ax.barh(fi_df["Feature"][::-1], fi_df["Importance"][::-1], color=cmap[::-1])
    ax.bar_label(bars, fmt="%.3f", padding=3, fontsize=8)
    ax.set_xlabel("Relative importance (normalised)")
    ax.set_title(f"Feature Importance — {result.best_algorithm}")
    plt.tight_layout()
    plt.show()
else:
    print("  (feature importance not available for this model type)")

# ══════════════════════════════════════════════════════════════════════════════
# 6. OOT METRICS — BEST MODEL
# ══════════════════════════════════════════════════════════════════════════════
_sec("⑥", f"OOT METRICS — BEST MODEL  ({result.best_algorithm})")
best_row = next(
    (r for r in result.leaderboard
     if r.get("algorithm") == result.best_algorithm
     and r.get("oot_metrics", {}).get(_pm_key, 0) == _best_oot_per_algo.get(result.best_algorithm, 0)),
    {}
)
oot = best_row.get("oot_metrics", {})
if oot:
    m_df = pd.DataFrame([{"Metric": k, "Value": f"{v:.4f}",
                           "Bar": "█" * int(v * 30)} for k, v in oot.items()])
    print(m_df.to_string(index=False))

    fig, ax = plt.subplots(figsize=(7, 3.2))
    bar_colors = ["#1976D2" if k == _pm_key else "#64B5F6" for k in oot]
    rects = ax.bar(list(oot.keys()), list(oot.values()), color=bar_colors)
    ax.bar_label(rects, fmt="%.4f", padding=3, fontsize=9)
    ax.set_ylim(0, 1.15)
    ax.set_ylabel("Score")
    ax.set_title(f"OOT Metrics — {result.best_algorithm}  (primary = {_pm_key})")
    legend = [mpatches.Patch(color="#1976D2", label=f"Primary ({_pm_key})"),
              mpatches.Patch(color="#64B5F6", label="Other metrics")]
    ax.legend(handles=legend, fontsize=8)
    plt.tight_layout()
    plt.show()

# ══════════════════════════════════════════════════════════════════════════════
# 7. THRESHOLDS + NARRATIVE
# ══════════════════════════════════════════════════════════════════════════════
_sec("⑦", "DECISION THRESHOLDS")
print(f"  F1-optimal threshold  :  {result.optimal_threshold:.4f}")
for k, v in (result.business_thresholds or {}).items():
    print(f"  {k:<32}  {v}")

_sec("⑧", "MODEL NARRATIVE")
print(summary)

print(f"\n{_BAR}")
print(f"  Artifacts  →  {result.run_dir}")
print(_BAR)
# Out:
# ════════════════════════════════════════════════════════════════
#   ①  DATA SPLIT
# ────────────────────────────────────────────────────────────────
#            Set    Rows         Snapshots Positive ratio
#          Train 500,000 2025-01 → 2025-05          5.01%
# OOT (hold-out) 100,000 2025-06 → 2025-06          5.11%
#
# ════════════════════════════════════════════════════════════════
#   ②  FEATURE SELECTION FUNNEL
# ────────────────────────────────────────────────────────────────
#   Input features                                 52  ████████████████████████████████████
#   After hygiene (constant/missing/card)          52  ████████████████████████████████████
#   After univariate IV filter                     47  ████████████████████████████████  (removed 5 total)
#   After redundancy / corr pruning                40  ███████████████████████████  (removed 12 total)
#   Final selected                                 40  ███████████████████████████  ◀ FINAL
#
#   Dropped by reason:
#     • Low IV (below threshold)             (  5)  existing_cc_flag, existing_product_count, credit_velocity_3m_6m, customer_id, debit_velocity_3m_6m
#     • Redundant (corr cluster)             (  7)  txn_count_6m, total_credit_amt_6m, salary_credit_amt_1m, total_debit_amt_6m, bounce_flag_3m, credit_debit_ratio_3m … +1 more
#
# ════════════════════════════════════════════════════════════════
#   ③  INFORMATION VALUE — SELECTED FEATURES  (real names, top 20)
# ────────────────────────────────────────────────────────────────
#                  Feature  IV IV band Leakage?
#                  segment   0
#      total_credit_amt_1m   0
#              net_flow_1m   0
#          avg_txn_size_1m   0
#        mcc_travel_amt_1m   0
#      total_credit_amt_3m   0
#             txn_count_1m   0
#       total_debit_amt_1m   0
#          bounce_count_1m   0
#            bounce_amt_1m   0
#          bounce_count_3m   0
#     digital_txn_ratio_1m   0
# mcc_entertainment_amt_1m   0
#           mandate_amt_1m   0
#         pos_debit_amt_1m   0
#  neft_rtgs_credit_amt_1m   0
#     adhoc_debit_count_1m   0
#   neft_rtgs_debit_amt_1m   0
#     mcc_ecommerce_amt_1m   0
#        mcc_retail_amt_1m   0
# ════════════════════════════════════════════════════════════════
#   ④  MODEL LEADERBOARD — ALL TRIALS
# ────────────────────────────────────────────────────────────────
# ★            Algorithm  CV score  OOT f1  OOT gini  OOT ks  OOT pr_auc  OOT precision  OOT recall  OOT roc_auc
# ★ HistGradientBoosting    0.1210  0.0000    0.4419  0.3157      0.1203         0.0000      0.0000       0.7210
#   HistGradientBoosting    0.1214  0.0000    0.4425  0.3203      0.1203         0.0000      0.0000       0.7213
#                XGBoost    0.1209  0.1607    0.4454  0.3211      0.1202         0.0911      0.6821       0.7227
#               LightGBM    0.1201  0.1620    0.4448  0.3168      0.1201         0.0921      0.6731       0.7224
#                XGBoost    0.1200  0.1614    0.4441  0.3189      0.1200         0.0918      0.6680       0.7220
#               LightGBM    0.1208  0.1608    0.4437  0.3181      0.1199         0.0913      0.6716       0.7218
#               LightGBM    0.1210  0.1615    0.4460  0.3223      0.1199         0.0915      0.6876       0.7230
#   HistGradientBoosting    0.1215  0.0000    0.4416  0.3172      0.1199         0.0000      0.0000       0.7208
#   HistGradientBoosting    0.1213  0.0000    0.4419  0.3185      0.1198         0.0000      0.0000       0.7209
#   HistGradientBoosting    0.1209  0.0000    0.4420  0.3166      0.1197         0.0000      0.0000       0.7210
#               LightGBM    0.1211  0.1618    0.4440  0.3198      0.1196         0.0921      0.6671       0.7220
#                XGBoost    0.1190  0.1665    0.4394  0.3135      0.1192         0.0960      0.6271       0.7197
#   HistGradientBoosting    0.1204  0.0000    0.4395  0.3132      0.1181         0.0000      0.0000       0.7198
#                XGBoost    0.1141  0.1855    0.4175  0.2993      0.1170         0.1158      0.4652       0.7088
#               LightGBM    0.1168  0.1647    0.4311  0.3049      0.1168         0.0950      0.6166       0.7156
#               LightGBM    0.1138  0.1681    0.4157  0.3020      0.1163         0.0988      0.5642       0.7079
#                XGBoost    0.1130  0.1730    0.4127  0.2968      0.1158         0.1038      0.5194       0.7064
#                XGBoost    0.1002  0.1723    0.3626  0.2684      0.1035         0.1165      0.3308       0.6813
# ════════════════════════════════════════════════════════════════
#   ⑤  FEATURE IMPORTANCE — HistGradientBoosting  (top 20, real names)
# ────────────────────────────────────────────────────────────────
#   (feature importance not available for this model type)
#
# ════════════════════════════════════════════════════════════════
#   ⑥  OOT METRICS — BEST MODEL  (HistGradientBoosting)
# ────────────────────────────────────────────────────────────────
#    Metric  Value                   Bar
# precision 0.0000
#    recall 0.0000
#        f1 0.0000
#   roc_auc 0.7210 █████████████████████
#    pr_auc 0.1203                   ███
#        ks 0.3157             █████████
#      gini 0.4419         █████████████
# ════════════════════════════════════════════════════════════════
#   ⑦  DECISION THRESHOLDS
# ────────────────────────────────────────────────────────────────
#   F1-optimal threshold  :  0.1053
#   f1_optimal                        0.10529090759904489
#   precision_50                      None
#   recall_80                         0.04346223761033223
#
# ════════════════════════════════════════════════════════════════
#   ⑧  MODEL NARRATIVE
# ────────────────────────────────────────────────────────────────
# The **HistGradientBoosting** model (trial 16) was selected as the best performing model based on Out-of-Time (OOT) PR_AUC, out of 36 trials. OOT performance metrics include: precision=0.0000, recall=0.0000, f1=0.0000, roc_auc=0.7210, pr_auc=0.1203, ks=0.3157, and gini=0.4419. The F1-optimal threshold identified is 0.105.
#
# ════════════════════════════════════════════════════════════════
#   Artifacts  →  artifacts\runs\2026-06-19_13-20-02
# ════════════════════════════════════════════════════════════════

# %%
# 5) Score new data with the saved bundle (no retraining, no LLM)
import joblib, numpy as np
bundle = joblib.load(f"{result.run_dir}/model_bundle.joblib")
def score(df_new):
    amap = bundle.get("alias_map")
    if amap:  # columns were aliased at train time -> rename incoming real names to aliases
        df_new = df_new.rename(columns=amap["forward"])
    d = bundle["cleaning_artifacts"].transform(df_new)
    feats = bundle["selected_raw_features"]
    num = [c for c in feats if c in d.select_dtypes(include=[np.number]).columns]
    cat = [c for c in feats if c not in num]
    X = bundle["preprocessor"].transform(d[num + cat])
    return bundle["model"].predict_proba(X)[:, 1]
print("scorer ready; threshold =", bundle["optimal_threshold"])
# Out:
# scorer ready; threshold = 0.10529090759904489

# %%
# ── 6) Cost & Token Summary — saved as CSV in the run artifact folder ─────────
import json, csv
from pathlib import Path

_cost_path = Path(result.run_dir) / "cost_summary.json"
if _cost_path.exists():
    _c = json.loads(_cost_path.read_text(encoding="utf-8"))
else:
    _c = {"input_tokens": 0, "cached_tokens": 0,
          "output_tokens": 0, "thinking_tokens": 0, "total_tokens": 0, "model": "—"}

_row = {
    "Use Case":         OBJECTIVE,
    "Model":            _c.get("model", cached_llm.model_id if USE_LLM else "—"),
    "Iteration ID":     Path(result.run_dir).name,
    "Prompt Tokens":    _c.get("input_tokens", 0),
    "Cached Tokens":    _c.get("cached_tokens", 0),
    "Output Tokens":    _c.get("output_tokens", 0),
    "Thinking Tokens":  _c.get("thinking_tokens", 0),
    "Total Tokens":     _c.get("total_tokens", 0),
}

# ── Print summary table in output cell ───────────────────────────────────────
_W = 64
print("═" * _W)
print("  TOKEN USAGE SUMMARY")
print("─" * _W)
for k, v in _row.items():
    print(f"  {k:<20}  {v}")
print("═" * _W)

# ── Write / append to a shared cost_log.csv in the artifacts root ─────────────
_artifacts_root = Path(result.run_dir).parent   # e.g. artifacts/runs/
_csv_path = _artifacts_root / "cost_log.csv"
_write_header = not _csv_path.exists()
with open(_csv_path, "a", newline="", encoding="utf-8") as _f:
    _w = csv.DictWriter(_f, fieldnames=list(_row.keys()))
    if _write_header:
        _w.writeheader()
    _w.writerow(_row)

print(f"\n  ✓ Row appended to:  {_csv_path}")
# Out:
# ════════════════════════════════════════════════════════════════
#   TOKEN USAGE SUMMARY
# ────────────────────────────────────────────────────────────────
#   Use Case              Build CC propensity model
#   Model                 gemini-2.5-flash-lite
#   Iteration ID          2026-06-19_13-20-02
#   Prompt Tokens         700
#   Cached Tokens         0
#   Output Tokens         1670
#   Thinking Tokens       0
#   Total Tokens          2370
# ════════════════════════════════════════════════════════════════
#
#   ✓ Row appended to:  artifacts\runs\cost_log.csv
